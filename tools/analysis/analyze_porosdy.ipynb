# %%
import sys
sys.path.insert(0, "C:/Users/RidwanJalali/Documents/code/poet/poet/utils")
from bohour.arudi_style import get_arudi_style
from bohour.bahr import Taweel,Kamel
from bohour.qafiah import get_qafiyah

# %%
x = """تَبْكِي السّحَابُ عَلَى فِرَاقِكَ يَا شَفَقْ
وَالْقَلْبُ يَشْكُو مَا أَصَابَهُ مِنْ حُرَقْ
فِي لَيْلَةٍ حَزِنَتْ عَلَيْكَ دُجَى السّهَا
وَجْدِي عَلَيْكَ يَزِيدُ مَعَ النّفْحِ العَبَقْ""".split("\n")[2:4]
x= "#".join(x)
arudi_style = get_arudi_style(x)[0][1]
kamel = Kamel()
is_valid=arudi_style in kamel.all_baits_combinations_patterns
arudi_style,is_valid
# Out:
# ('1010110111011011101101010110111011101010110', False)

# %%
arudi_style = get_arudi_style(x)
arudi_style
# Out:
# [['في ليلتن حزنت عليك دجسسهاوجدي عليك يزيد مع ننفح لعبق',
#   '1010110111011011101101010110111011101010110']]

# %%
all_combinations = Kamel().all_baits_combinations_patterns
all_combinations[7]
# Out:
# '11101101110110111011011101101010110111010'

# %%
x = """
تَبْكِي السّحَابُ عَلَى فِرَاقِكَ يَا شَفَقْ
وَالْقَلْبُ يَشْكُو مَا أَصَابَهُ مِنْ حُرَقْ
فِي لَيْلَةٍ حَزِنَتْ عَلَيْكَ دُجَى السّهَا
وَجْدِي عَلَيْكَ يَزِيدُ مَعَ نَفْحِ العَبَقْ""".split("\n")
for i in x:
    print(i)
    print(get_qafiyah(i))
# Out:
# لَقَدْ جِئْتُ أَشْكُو الْحُزْنَ فِي الْقَلْبِ مُغْرَقًا
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[18], line 7
#       5 for i in x:
#       6     print(i)
# ----> 7     print(get_qafiyah(i))
#
# File C:\Users/RidwanJalali/Documents/code/poet/poet/evaluation\bohour\qafiah.py:154, in get_qafiyah(baits, short)
#     152 get_qafiah = get_qafiah_type_short if short is True else get_qafiah_type
#     153 for bait in baits:
# --> 154     results.append((get_rawwy_char(bait), get_qafiah(bait)))
#     155 return results
#
# File C:\Users/RidwanJalali/Documents/code/poet/poet/evaluation\bohour\qafiah.py:23, in get_rawwy_char(bait, with_index)
#      21 while True:
#      22     last_char = clean_bait[i]
# ---> 23     second_last_char = clean_bait[i - 1]
#      24     if second_last_char == "آ":
#      25         second_last_char = "ا"
#
# ...
