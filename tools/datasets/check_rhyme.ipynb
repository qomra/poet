# %%
from datasets import load_from_disk

# %%
ds = load_from_disk("../../kb/ashaar_with_rhymes")

# %%
ds[0]
# Out:
# {'poem title': 'أصبح الملك للذي فطر الخلق',
#  'poem meter': 'بحر الخفيف',
#  'poem verses': ['أَصبَحَ المُلك لِلَّذي فَطر الخَل',
#   'قَ بِتَقديرٍ للعَزيز العَليمِ',
#   'غافر الذَنب للمسيءِ بِعَفوٍ',
#   'قابل التَوب ذي العَطاء العَميمِ',
#   'مُرسل المُصطَفى البَشير إِلَينا',
#   'رَحمة مِنهُ بِالكَلام القَديمِ',
#   'رَبَنا رَبّنا إِلَيكَ أَنينا',
#   'فَأَجرنا مِن حَر نار الجَحيمِ',
#   'وَاكفِنا شَرّ ما نَخاف بِلُطفٍ',
#   'يا عَظيماً يَرجى لِكُل عَظيمِ',
#   'وَتَقبل أَعمالَنا وَاعفُ عَنا',
#   'وَأَنلنا دُخول دار النَعيمِ',
#   'بِنَبي بَعثَتهُ فَهَدانا',
#   'لِصِراط مِن الهُدى مُستَقيمِ',
#   'وَبِمَن نَحنُ في حِماهُ مَدى الدَهر',
#   'أَخيهِ يَحيى الحصور الكَريمِ',
#   'أَدرك أَدرك قَوماً أَتوا بافتقار',
#   'وَاِنكِسار وَمَدمَع مَسجومِ',
#   'شَهدت أَرواحَهُم أَنكَ اللَهُ',
#   'وَجاءوا بِكُل قَلبٍ سَليم'],
#  'poem theme': 'قصيدة دينية',
#  'poem url': 'https://www.aldiwan.net/poem16182.html',
#  'poet name': 'الامير منجك باشا',
# ...

# %%
# get items that has longer_rhyme != ""
filtered_dataset = ds.filter(lambda item: item['longer_rhyme'] != '')
# Out:
# Filter: 100%|██████████| 254630/254630 [00:08<00:00, 29210.38 examples/s]

# %%
index = 0

# %%
index +=1
verses = filtered_dataset[index]["poem verses"]
verses
# Out:
# ['يُدير عَليَّ كاسات الحميا',
#  'ضَحوك السنَّ بَراق المَحيا',
#  'إِذا ذَكَرت صِفات الحُسن مِنهُ',
#  'فَما سَعدي وَما أَسما وَميّا',
#  'يَقول الوَرد في خَديهِ هَبوا',
#  'إِلى اللذات قَبل الفَوت هَيا',
#  'فَإِن العُمر أَيام التَلاقي',
#  'وَساعات البدار أَجل مهيا',
#  'فَقُلت نَعم لَو أَنَّ الحَظ حَظ',
#  'وَزارَ السَعد نادينا وَحيا',
#  'وَلَكن لَو رَكبت الريح طَرفاً',
#  'وَكانَ البَرق سَوطاً في يَديا',
#  'وَسابقني الجهول عَلى حِمار',
#  'لَكانَ السَبق في الدُنيا عليا',
#  'وَلَو أَعيا الزَمان الوَغد همٌّ',
#  'فَأَعجزهُ لِأَرسلهُ اليّا',
#  'وَلَو أَنَّ السَّعادةَ بالتَّمني',
#  'رَأَيت مَنازِلي فَوقَ الثُّرَيّا']

# %%
filtered_dataset[0]
# Out:
# {'poem title': 'يعد علي أنفاسي ذنوبا',
#  'poem meter': 'بحر الوافر',
#  'poem verses': ['يعد عَليَّ أَنفاسي ذُنوباً',
#   'إِذا ما قُلت أَفديهِ حَبيبا',
#   'وَأَبعد ما يَكون الود مِنهُ',
#   'إِذا ما باتَ مِن أَمَلي قَريبا',
#   'حَبيب كُلَّما يَلقاهُ صَبٌّ',
#   'يَصير عَلَيهِ مَن يَهوى رَقيبا',
#   'يَعاف مَنازل العُشاق كَبراً',
#   'وَلَو فَرشت مَسالكها قُلوبا',
#   'فَلو حَمل النَسيم إِلَيهِ مِني',
#   'سَلاماً راحَ يَمنَعَهُ هُبوبا',
#   'أَغار عَلى الجَفا مِنهُ لِغَيري',
#   'فَلَيتَ جَفاهُ أَضحى لي نَصيبا',
#   'وَأَعشَق أَعيُن الرقباءَ فيهِ',
#   'وَلَو مَلَئت عُيونَهُم عُيوبا',
#   'لَقَد أَخَذَ الهَوى بِزِمام قَلبي',
#   'وَصَير دَمع أَجفاني صَبيبا',
#   'وَما أَملت في أَهلي نَصيراً',
#   'فَكَيفَ الآن أَطلبهُ غَريبا',
#   'وَأَقصِد أَن يَعيد رُوا شَبابي',
#   'زَمان غادر الولدان شِيبا',
#   'وَما خَفيت عَلَيَّ الناس حَتّى',
#   'أَروم اليَوم مِن رَخم حَليبا',
#   'أَذا ظَنَ الذُباب خَشيتُ مِنهُ',
#   'لِفَقد مُساعِدي يُلفى مُجيبا',
#   'وَهب أَني حَكيت الشاة ضُعفاً',
# ...
